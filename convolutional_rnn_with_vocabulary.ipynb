# %%
import tensorflow as tf
import tensorflow.keras.layers as layers
from tensorflow.keras.regularizers import l2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm, trange
from itertools import islice
from collections import OrderedDict

from preprocessing.numeric import *
from preprocessing.tokens import *

RANDOM_SEED = 2
tf.random.set_seed(RANDOM_SEED)

tf.__version__, tf.keras.__version__
# Out:
# ('2.2.0', '2.3.0-tf')

# %%
train = tf.data.experimental.make_csv_dataset("data/train_small.tsv",
                                           field_delim="\t",
                                           batch_size=1000,
#                                            compression_type="GZIP",
                                           label_name="Click",
                                           num_epochs=1)

test = tf.data.experimental.make_csv_dataset("data/test.tsv",
                                           field_delim="\t",
                                           batch_size=10_000,
                                           label_name="Click",
                                           num_epochs=1)

NUMERIC_FEATURES = ["Depth", "Position", "Age", "UserID", "AdvertiserId"]
CATEGORICAL_FEATURES = ["Gender"]
TOKENS_FEATURES = ["AdKeyword_tokens", "AdTitle_tokens", "AdDescription_tokens", "Query_tokens"]

# %% [markdown]
# ---
# #### Numeric features

# %%
GENDER_SIZE = 2

train = train\
    .map(PackNumericFeatures(NUMERIC_FEATURES))\
    .map(Normalize(NUMERIC_FEATURES))\
    .map(Categorize("Gender", GENDER_SIZE))

test = test\
    .map(PackNumericFeatures(NUMERIC_FEATURES))\
    .map(Normalize(NUMERIC_FEATURES))\
    .map(Categorize("Gender", GENDER_SIZE))

# %% [markdown]
# ---
# #### Sequence of tokens features
# AdKeyword_tokens, AdTitle_tokens, AdDescription_tokens, Query_tokens
#
# Jak stworzyć słownik do modelu?

# %%
n_words = {
    "AdKeyword_tokens": 5_000,
    "AdTitle_tokens": 5_000,
    "AdDescription_tokens": 5_000,
    "Query_tokens": 5_000
}

max_length = {
    "AdKeyword_tokens": 6,
    "AdTitle_tokens": 14,
    "AdDescription_tokens": 30,
    "Query_tokens": 7
}

vocab_path = {
    "AdKeyword_tokens": "data/vocab/AdKeyword_tokens.txt",
    "AdTitle_tokens": "data/vocab/AdTitle_tokens.txt",
    "AdDescription_tokens": "data/vocab/AdDescription_tokens.txt",
    "Query_tokens": "data/vocab/Query_tokens.txt"
}

OOV_WORDS = 10

for name in TOKENS_FEATURES:
    train = train.map(TokenizeWithVocabFile(name, vocab_size=n_words[name], max_length=max_length[name], vocab_file=vocab_path[name], oov_buckets=OOV_WORDS))
    test = test.map(TokenizeWithVocabFile(name, vocab_size=n_words[name], max_length=max_length[name], vocab_file=vocab_path[name], oov_buckets=OOV_WORDS))

# %%
next(iter(train))[0]["AdKeyword_tokens"]
# Out:
# <tf.Tensor: shape=(1000, 6), dtype=int64, numpy=
# array([[3017, 2405,    6,    0,    0,    0],
#        [   4,    2,    1,    0,    0,    0],
#        [  47,    0,    0,    0,    0,    0],
#        ...,
#        [   1,   27,    0,    0,    0,    0],
#        [   4,    0,    0,    0,    0,    0],
#        [ 380,    0,    0,    0,    0,    0]])>

# %% [markdown]
# ---
# #### Model

# %%
EMBEDDING_DIM = 32

x_num_input = tf.keras.Input(shape=(len(NUMERIC_FEATURES), ), name="numeric")
x_gender_input = tf.keras.Input(shape=(GENDER_SIZE, ), name="Gender")
x_num = tf.keras.layers.Concatenate()([x_gender_input, x_num_input])
# x_cat_input = tf.keras.Input(shape=(3, ), name="Gender")
# x_cat = tf.feature_column.categorical_column_with_vocabulary_list("Gender", [0, 1, 2])
# x_num = tf.keras.layers.Concatenate(axis=-1)([x_num_input, x_cat])
x_num = tf.keras.layers.Dense(512, activation="relu")(x_num)

embeddings = []
embedding_inputs = []
for name in TOKENS_FEATURES:
    embedding_layer = tf.keras.layers.Embedding(input_dim=n_words[name] + OOV_WORDS, 
                                                output_dim=EMBEDDING_DIM, 
                                                mask_zero=False, 
                                                input_length=max_length[name])
    x_emb_input = tf.keras.Input(shape=(max_length[name]), name=name)  # model doesn't work with ragged tensor
    embedding_inputs.append(x_emb_input)  # appending to inputs
    x_emb = embedding_layer(x_emb_input)
    x_emb = tf.keras.layers.Conv1D(64, kernel_size=3, kernel_regularizer=l2(0.01), use_bias=False)(x_emb)
    x_emb = tf.keras.layers.BatchNormalization()(x_emb)
    x_emb = tf.keras.layers.Dropout(0.5)(x_emb)
    x_emb = tf.keras.layers.MaxPool1D(2)(x_emb)
    x_emb = tf.keras.layers.LSTM(32)(x_emb)
    x_emb = tf.keras.layers.Dropout(0.1)(x_emb)
    embeddings.append(x_emb)

x = tf.keras.layers.Concatenate(axis=-1)([x_num, *embeddings])

feedforward = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation="relu", use_bias=False, kernel_regularizer=l2(0.01)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation="sigmoid", name="prediction"),
])

output = feedforward(x)

model = tf.keras.Model(inputs=[x_num_input, x_gender_input, *embedding_inputs], outputs=output, name="Adclick")

model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=["accuracy", tf.keras.metrics.AUC(name="auc")]
)

# %%
model.summary()
# Out:
# Model: "Adclick"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# AdKeyword_tokens (InputLayer)   [(None, 6)]          0
# __________________________________________________________________________________________________
# AdTitle_tokens (InputLayer)     [(None, 14)]         0
# __________________________________________________________________________________________________
# AdDescription_tokens (InputLaye [(None, 30)]         0
# __________________________________________________________________________________________________
# Query_tokens (InputLayer)       [(None, 7)]          0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 6, 32)        160320      AdKeyword_tokens[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 14, 32)       160320      AdTitle_tokens[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 30, 32)       160320      AdDescription_tokens[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 7, 32)        160320      Query_tokens[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 4, 64)        6144        embedding[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 12, 64)       6144        embedding_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 28, 64)       6144        embedding_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 5, 64)        6144        embedding_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 4, 64)        256         conv1d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 12, 64)       256         conv1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 28, 64)       256         conv1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 5, 64)        256         conv1d_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 4, 64)        0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 12, 64)       0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 28, 64)       0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 5, 64)        0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# Gender (InputLayer)             [(None, 2)]          0
# __________________________________________________________________________________________________
# numeric (InputLayer)            [(None, 5)]          0
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 2, 64)        0           dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 6, 64)        0           dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 14, 64)       0           dropout_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 2, 64)        0           dropout_6[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 7)            0           Gender[0][0]
#                                                                  numeric[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 32)           12416       max_pooling1d[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 32)           12416       max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 32)           12416       max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 32)           12416       max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          4096        concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32)           0           lstm[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32)           0           lstm_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 32)           0           lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 32)           0           lstm_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 640)          0           dense[0][0]
#                                                                  dropout_1[0][0]
#                                                                  dropout_3[0][0]
#                                                                  dropout_5[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 1)            82561       concatenate_1[0][0]
# ==================================================================================================
# Total params: 803,201
# Trainable params: 802,433
# Non-trainable params: 768
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, expand_nested=True, show_shapes=True)

# %%
def schedule(epoch, lr):
    print(epoch)
    if epoch == 0:
        return 0.1
    elif epoch == 1:
        return 0.01
    else:
        return 0.001
scheduler = tf.keras.callbacks.LearningRateScheduler(schedule, verbose=1)

history = model.fit(train, validation_data=test, epochs=10, callbacks=[scheduler])
# Out:
# 0
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.1.
# Epoch 1/10
# 100/100 [==============================] - 59s 593ms/step - loss: 1.3000 - accuracy: 0.9339 - auc: 0.5209 - val_loss: 0.2757 - val_accuracy: 0.9525 - val_auc: 0.5603 - lr: 0.1000
# 1
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 2/10
# 100/100 [==============================] - 59s 589ms/step - loss: 0.2113 - accuracy: 0.9509 - auc: 0.5732 - val_loss: 0.2021 - val_accuracy: 0.9525 - val_auc: 0.5639 - lr: 0.0100
# 2
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/10
# 100/100 [==============================] - 57s 567ms/step - loss: 0.1972 - accuracy: 0.9509 - auc: 0.5890 - val_loss: 0.1916 - val_accuracy: 0.9525 - val_auc: 0.5907 - lr: 0.0010
# 3
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/10
# 100/100 [==============================] - 60s 596ms/step - loss: 0.1959 - accuracy: 0.9509 - auc: 0.5933 - val_loss: 0.1915 - val_accuracy: 0.9525 - val_auc: 0.5889 - lr: 0.0010
# 4
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/10
# 100/100 [==============================] - 66s 656ms/step - loss: 0.1958 - accuracy: 0.9509 - auc: 0.5914 - val_loss: 0.1915 - val_accuracy: 0.9525 - val_auc: 0.5875 - lr: 0.0010
# 5
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/10
# 100/100 [==============================] - 63s 629ms/step - loss: 0.1962 - accuracy: 0.9509 - auc: 0.5935 - val_loss: 0.1921 - val_accuracy: 0.9525 - val_auc: 0.5878 - lr: 0.0010
# 6
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/10
# 100/100 [==============================] - 67s 673ms/step - loss: 0.1965 - accuracy: 0.9509 - auc: 0.5896 - val_loss: 0.1929 - val_accuracy: 0.9525 - val_auc: 0.5840 - lr: 0.0010
# 7
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/10
# 100/100 [==============================] - 69s 685ms/step - loss: 0.1960 - accuracy: 0.9509 - auc: 0.5974 - val_loss: 0.1930 - val_accuracy: 0.9525 - val_auc: 0.5800 - lr: 0.0010
# 8
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/10
# 100/100 [==============================] - 72s 723ms/step - loss: 0.1964 - accuracy: 0.9509 - auc: 0.5952 - val_loss: 0.1931 - val_accuracy: 0.9525 - val_auc: 0.5841 - lr: 0.0010
# 9
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/10
# 100/100 [==============================] - 64s 641ms/step - loss: 0.1967 - accuracy: 0.9509 - auc: 0.5940 - val_loss: 0.1926 - val_accuracy: 0.9525 - val_auc: 0.5858 - lr: 0.0010
