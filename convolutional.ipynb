# %%
import tensorflow as tf
import tensorflow.keras.layers as layers
from tensorflow.keras.regularizers import l2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm, trange
from itertools import islice
from collections import OrderedDict

from preprocessing.numeric import *
from preprocessing.tokens import *

RANDOM_SEED = 2
tf.random.set_seed(RANDOM_SEED)

tf.__version__, tf.keras.__version__
# Out:
# ('2.2.0', '2.3.0-tf')

# %%
train = tf.data.experimental.make_csv_dataset("data/train_10M.tsv",
                                           field_delim="\t",
                                           batch_size=1000,
#                                            compression_type="GZIP",
                                           label_name="Click",
                                           num_epochs=1)

test = tf.data.experimental.make_csv_dataset("data/test.tsv",
                                           field_delim="\t",
                                           batch_size=10_000,
                                           label_name="Click",
                                           num_epochs=1)

NUMERIC_FEATURES = ["Depth", "Position", "Gender", "Age", "UserID", "AdvertiserId"]
TOKENS_FEATURES = ["AdKeyword_tokens", "AdTitle_tokens", "AdDescription_tokens", "Query_tokens"]

# %% [markdown]
# ---
# #### Numeric features

# %%
train = train\
    .map(PackNumericFeatures(NUMERIC_FEATURES))\
    .map(Normalize(NUMERIC_FEATURES))

test = test\
    .map(PackNumericFeatures(NUMERIC_FEATURES))\
    .map(Normalize(NUMERIC_FEATURES))

# %% [markdown]
# ---
# #### Sequence of tokens features
# AdKeyword_tokens, AdTitle_tokens, AdDescription_tokens, Query_tokens
#
# Jak stworzyć słownik do modelu?

# %%
n_words = {
    "AdKeyword_tokens": 5_000,
    "AdTitle_tokens": 5_000,
    "AdDescription_tokens": 5_000,
    "Query_tokens": 5_000
}

max_length = {
    "AdKeyword_tokens": 6,
    "AdTitle_tokens": 14,
    "AdDescription_tokens": 30,
    "Query_tokens": 7
}

for name in TOKENS_FEATURES:
    train = train.map(Tokenize(name, vocab_size=n_words[name], max_length=max_length[name]))
    test = test.map(Tokenize(name, vocab_size=n_words[name], max_length=max_length[name]))

# %% [markdown]
# ---
# #### Model

# %%
EMBEDDING_DIM = 32

x_num_input = tf.keras.Input(shape=(6, ), name="numeric")
# x_cat_input = tf.keras.Input(shape=(3, ), name="Gender")
# x_cat = tf.feature_column.categorical_column_with_vocabulary_list("Gender", [0, 1, 2])
# x_num = tf.keras.layers.Concatenate(axis=-1)([x_num_input, x_cat])
x_num = tf.keras.layers.Dense(512, activation="relu")(x_num_input)

embeddings = []
embedding_inputs = []
for name in TOKENS_FEATURES:
    embedding_layer = tf.keras.layers.Embedding(input_dim=n_words[name], 
                                                output_dim=EMBEDDING_DIM, 
                                                mask_zero=False, 
                                                input_length=max_length[name])
    x_emb_input = tf.keras.Input(shape=(max_length[name]), name=name)  # model doesn't work with ragged tensor
    embedding_inputs.append(x_emb_input)  # appending to inputs
    x_emb = embedding_layer(x_emb_input)
    x_emb = tf.keras.layers.Conv1D(64, kernel_size=3, kernel_regularizer=l2(0.01), use_bias=False)(x_emb)
    x_emb = tf.keras.layers.BatchNormalization()(x_emb)
    x_emb = tf.keras.layers.Dropout(0.5)(x_emb)
    x_emb = tf.keras.layers.GlobalMaxPooling1D()(x_emb)
#     x_emb = tf.keras.layers.Lambda(lambda x: tf.reduce_mean(x, axis=1, keepdims=False, name="Average"))(x_emb)
    embeddings.append(x_emb)

x = tf.keras.layers.Concatenate(axis=-1)([x_num, *embeddings])

feedforward = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation="relu", use_bias=False, kernel_regularizer=l2(0.01)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation="sigmoid", name="prediction"),
])

output = feedforward(x)

model = tf.keras.Model(inputs=[x_num_input, *embedding_inputs], outputs=output, name="Adclick")

model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=["accuracy", tf.keras.metrics.AUC(name="auc")]
)

# %%
model.summary()
# Out:
# Model: "Adclick"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# AdKeyword_tokens (InputLayer)   [(None, 6)]          0
# __________________________________________________________________________________________________
# AdTitle_tokens (InputLayer)     [(None, 14)]         0
# __________________________________________________________________________________________________
# AdDescription_tokens (InputLaye [(None, 30)]         0
# __________________________________________________________________________________________________
# Query_tokens (InputLayer)       [(None, 7)]          0
# __________________________________________________________________________________________________
# embedding_38 (Embedding)        (None, 6, 32)        160000      AdKeyword_tokens[0][0]
# __________________________________________________________________________________________________
# embedding_39 (Embedding)        (None, 14, 32)       160000      AdTitle_tokens[0][0]
# __________________________________________________________________________________________________
# embedding_40 (Embedding)        (None, 30, 32)       160000      AdDescription_tokens[0][0]
# __________________________________________________________________________________________________
# embedding_41 (Embedding)        (None, 7, 32)        160000      Query_tokens[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 4, 64)        6144        embedding_38[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 12, 64)       6144        embedding_39[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 28, 64)       6144        embedding_40[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 5, 64)        6144        embedding_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 4, 64)        256         conv1d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 12, 64)       256         conv1d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 28, 64)       256         conv1d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 5, 64)        256         conv1d_41[0][0]
# __________________________________________________________________________________________________
# numeric (InputLayer)            [(None, 6)]          0
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 4, 64)        0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 12, 64)       0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 28, 64)       0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 5, 64)        0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 512)          3584        numeric[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_24 (Global (None, 64)           0           dropout_5[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_25 (Global (None, 64)           0           dropout_6[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_26 (Global (None, 64)           0           dropout_7[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_27 (Global (None, 64)           0           dropout_8[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 768)          0           dense_20[0][0]
#                                                                  global_max_pooling1d_24[0][0]
#                                                                  global_max_pooling1d_25[0][0]
#                                                                  global_max_pooling1d_26[0][0]
#                                                                  global_max_pooling1d_27[0][0]
# __________________________________________________________________________________________________
# sequential_9 (Sequential)       (None, 1)            98945       concatenate_9[0][0]
# ==================================================================================================
# Total params: 768,129
# Trainable params: 767,361
# Non-trainable params: 768
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, expand_nested=True, show_shapes=True)

# %%
def schedule(epoch, lr):
    print(epoch)
    if epoch == 0:
        return 0.1
    elif epoch == 1:
        return 0.01
    else:
        return 0.001
scheduler = tf.keras.callbacks.LearningRateScheduler(schedule, verbose=1)

history = model.fit(train, validation_data=test, epochs=10, callbacks=[scheduler])
# Out:
# 0
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.1.
# Epoch 1/10
# 10000/10000 [==============================] - 926s 93ms/step - loss: 0.8017 - accuracy: 0.9526 - auc: 0.6323 - val_loss: 0.9788 - val_accuracy: 0.8298 - val_auc: 0.6587 - lr: 0.1000
# 1
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 2/10
# 10000/10000 [==============================] - 975s 98ms/step - loss: 0.2239 - accuracy: 0.9530 - auc: 0.7002 - val_loss: 0.3142 - val_accuracy: 0.9525 - val_auc: 0.6476 - lr: 0.0100
# 2
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/10
# 10000/10000 [==============================] - 924s 92ms/step - loss: 0.1812 - accuracy: 0.9531 - auc: 0.7156 - val_loss: 0.2202 - val_accuracy: 0.9525 - val_auc: 0.6939 - lr: 0.0010
# 3
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/10
# 10000/10000 [==============================] - 995s 100ms/step - loss: 0.1811 - accuracy: 0.9531 - auc: 0.7180 - val_loss: 0.2199 - val_accuracy: 0.9525 - val_auc: 0.6932 - lr: 0.0010
# 4
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/10
#   445/10000 [>.............................] - ETA: 15:06 - loss: 0.1918 - accuracy: 0.9497 - auc: 0.7047
